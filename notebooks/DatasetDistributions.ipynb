# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os
from matplotlib.patches import Rectangle

# %%
test = pd.read_csv('../pipeline/sim_lcs_output/add/add_f1000_maf0.4/additive_cens0.8_surv', sep = '\t', header = 0)
test.head()
# Out:
#    N0  N1  N2  N3  N4  N5  N6  N7  N8  N9  ...  N993  N994  N995  N996  M0P5  \
# 0   1   0   0   0   0   2   1   1   0   0  ...     2     0     2     2     2
# 1   1   1   1   1   1   0   0   1   0   0  ...     2     0     1     0     2
# 2   0   2   0   2   0   1   0   1   0   0  ...     0     0     0     0     2
# 3   0   1   0   0   1   1   2   1   0   0  ...     1     1     2     0     1
# 4   1   1   0   2   1   0   0   2   0   0  ...     0     0     1     1     2
#
#    M0P6  M1P2  eventTime  eventStatus  inst
# 0     0     1         74            0     1
# 1     0     1         82            0     2
# 2     0     1         85            0     3
# 3     1     1         10            1     4
# 4     0     0         94            0     5
#
# [5 rows x 1003 columns]

# %%
test0 = test.loc[test['eventStatus'] == 0.0]
test1 = test.loc[test['eventStatus'] == 1.0]
test0.shape
test1.shape
# Out:
# (180, 1003)

# %%
#Bar plot to show proportion of censoring AND distribution of event times

# %%
plt.figure(figsize=(6, 4))
plt.xlim([0,101])
#plt.ylim([0,101])
plt.xlabel('True Event Times', fontsize=14)
plt.ylabel('# of Instances', fontsize=14)
plt.hist(x=test1['eventTime'], bins=15, color='black', alpha=0.7, rwidth=0.85)
plt.hist(x=test0['eventTime'], bins=15, color='lightgrey', alpha=0.7, rwidth=0.85)

#create legend
handles = [Rectangle((0,0),1,1,color=c,ec="k") for c in ['black','lightgrey']]
labels= ["Event","Censored"]
plt.legend(handles, labels)

plt.savefig("../output/Figure8A.png")
plt.show()

# %%
test = pd.read_csv('../pipeline_guassian/sim_lcs_output/add/add_f1000_maf0.4/additive_cens0.8_surv', sep = '\t', header = 0)
test.head()
# Out:
#    N0  N1  N2  N3  N4  N5  N6  N7  N8  N9  ...  N993  N994  N995  N996  M0P5  \
# 0   1   0   0   0   0   2   1   1   0   0  ...     2     0     2     2     2
# 1   1   1   1   1   1   0   0   1   0   0  ...     2     0     1     0     2
# 2   0   2   0   2   0   1   0   1   0   0  ...     0     0     0     0     2
# 3   0   1   0   0   1   1   2   1   0   0  ...     1     1     2     0     1
# 4   1   1   0   2   1   0   0   2   0   0  ...     0     0     1     1     2
#
#    M0P6  M1P2  eventTime  eventStatus  inst
# 0     0     1         62            0     1
# 1     0     1         25            0     2
# 2     0     1         57            0     3
# 3     1     1         20            0     4
# 4     0     0         62            1     5
#
# [5 rows x 1003 columns]

# %%
test0 = test.loc[test['eventStatus'] == 0.0]
test1 = test.loc[test['eventStatus'] == 1.0]
test0.shape
test1.shape
# Out:
# (201, 1003)

# %%
#Bar plot to show proportion of censoring AND distribution of event times

# %%
plt.figure(figsize=(6, 4))
plt.xlim([0,101])
#plt.ylim([0,101])
plt.xlabel('True Event Times', fontsize=14)
plt.ylabel('# of Instances', fontsize=14)
plt.hist(x=test1['eventTime'], bins=15, color='black', alpha=0.7, rwidth=0.85)
plt.hist(x=test0['eventTime'], bins=15, color='lightgrey', alpha=0.7, rwidth=0.85)

#create legend
handles = [Rectangle((0,0),1,1,color=c,ec="k") for c in ['black','lightgrey']]
labels= ["Event","Censored"]
plt.legend(handles, labels)

plt.savefig("../output/Figure8B.png")
plt.show()
