# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/harshbandhey/Local/Cedars/Urbslab/survival-LCS-Final/pipeline_final/sim_lcs_output/het/ibs_data_heterogeneous.txt')

# %%
df1 = pd.read_csv('/Users/harshbandhey/Local/Cedars/Urbslab/survival-LCS-Final/pipeline_final/sim_lcs_output/add/ibs_data_additive.txt')

# %%
l1 = list(df.columns)

# %%
l2 = list(df1.columns)

# %%
for col in df.columns:
    if col != 'times' and 'het' not in col:
        df=df.drop(col, axis=1)

# %%
def fun(col_name='me_f100_maf0.2_cens0.1'):
    temp_df = df[[col_name, 'times']]
    temp_df = temp_df.dropna()
    try:
        val = np.trapz(temp_df[col_name], temp_df['times']) / (list(temp_df['times'])[-1] - list(temp_df['times'])[0])
    except Exception as e:
#         print(col_name, e)
        val = np.nan
    return val

# %%
df
# Out:
#      times  het_f100_maf0.2_cens0.1  het_f100_maf0.2_cens0.1_ci_lower  \
# 0      0.0                      NaN                               NaN
# 1      1.0                 0.003001                          0.003001
# 2      2.0                 0.003016                          0.003016
# 3      3.0                 0.005384                          0.005384
# 4      4.0                 0.017245                          0.004512
# ..     ...                      ...                               ...
# 96    96.0                      NaN                               NaN
# 97    97.0                      NaN                               NaN
# 98    98.0                      NaN                               NaN
# 99    99.0                      NaN                               NaN
# 100  100.0                      NaN                               NaN
#
#      het_f100_maf0.2_cens0.1_ci_upper  het_f100_maf0.2_cens0.4  \
# 0                                 NaN                      NaN
# 1                            0.003001                 0.008611
# 2                            0.003016                 0.033397
# 3                            0.005384                 0.070842
# 4                            0.033683                 0.120806
# ..                                ...                      ...
# 96                                NaN                 0.028032
# 97                                NaN                      NaN
# 98                                NaN                      NaN
# 99                                NaN                      NaN
# 100                               NaN                      NaN
#
#      het_f100_maf0.2_cens0.4_ci_lower  het_f100_maf0.2_cens0.4_ci_upper  \
# 0                                 NaN                               NaN
# 1                           -0.000670                          0.020166
# 2                            0.021609                          0.048072
# 3                            0.056749                          0.088386
# 4                            0.110079                          0.134161
# ..                                ...                               ...
# 96                           0.028032                          0.028032
# 97                                NaN                               NaN
# 98                                NaN                               NaN
# 99                                NaN                               NaN
# 100                               NaN                               NaN
#
#      het_f100_maf0.2_cens0.8  het_f100_maf0.2_cens0.8_ci_lower  \
# 0                        NaN                               NaN
# 1                   0.000371                          0.000371
# 2                   0.007709                          0.007709
# 3                   0.011988                          0.011988
# 4                   0.031612                          0.031612
# ..                       ...                               ...
# 96                       NaN                               NaN
# 97                       NaN                               NaN
# 98                       NaN                               NaN
# 99                       NaN                               NaN
# 100                      NaN                               NaN
#
#      het_f100_maf0.2_cens0.8_ci_upper  ...  \
# 0                                 NaN  ...
# 1                            0.000371  ...
# 2                            0.007709  ...
# 3                            0.011988  ...
# 4                            0.031612  ...
# ..                                ...  ...
# 96                                NaN  ...
# 97                                NaN  ...
# 98                                NaN  ...
# 99                                NaN  ...
# 100                               NaN  ...
#
#      het_f10000_maf0.2_cens0.8_ci_upper  het_f10000_maf0.4_cens0.1  \
# 0                                   NaN                        NaN
# 1                                   NaN                   0.001499
# 2                                   NaN                   0.001499
# 3                                   NaN                   0.002999
# 4                                   NaN                   0.002999
# ..                                  ...                        ...
# 96                                  NaN                        NaN
# 97                                  NaN                        NaN
# 98                                  NaN                        NaN
# 99                                  NaN                        NaN
# 100                                 NaN                        NaN
#
#      het_f10000_maf0.4_cens0.1_ci_lower  het_f10000_maf0.4_cens0.1_ci_upper  \
# 0                                   NaN                                 NaN
# 1                             -0.001499                            0.005370
# 2                             -0.001499                            0.005370
# 3                             -0.002999                            0.010741
# 4                             -0.002999                            0.010741
# ..                                  ...                                 ...
# 96                                  NaN                                 NaN
# 97                                  NaN                                 NaN
# 98                                  NaN                                 NaN
# 99                                  NaN                                 NaN
# 100                                 NaN                                 NaN
#
#      het_f10000_maf0.4_cens0.4  het_f10000_maf0.4_cens0.4_ci_lower  \
# 0                          NaN                                 NaN
# 1                     0.015110                            0.005294
# 2                     0.029250                           -0.000344
# 3                     0.042431                            0.013393
# 4                     0.049429                            0.020546
# ..                         ...                                 ...
# 96                         NaN                                 NaN
# 97                         NaN                                 NaN
# 98                         NaN                                 NaN
# 99                         NaN                                 NaN
# 100                        NaN                                 NaN
#
#      het_f10000_maf0.4_cens0.4_ci_upper  het_f10000_maf0.4_cens0.8  \
# 0                                   NaN                        NaN
# 1                              0.027332               0.000000e+00
# 2                              0.066095               0.000000e+00
# 3                              0.078584               0.000000e+00
# 4                              0.085388               1.551731e-08
# ..                                  ...                        ...
# 96                                  NaN               1.669001e-03
# 97                                  NaN                        NaN
# 98                                  NaN                        NaN
# 99                                  NaN                        NaN
# 100                                 NaN                        NaN
#
#      het_f10000_maf0.4_cens0.8_ci_lower  het_f10000_maf0.4_cens0.8_ci_upper
# 0                                   NaN                                 NaN
# 1                          0.000000e+00                        0.000000e+00
# 2                          0.000000e+00                        0.000000e+00
# 3                          0.000000e+00                        0.000000e+00
# 4                         -1.551731e-08                        5.558284e-08
# ..                                  ...                                 ...
# 96                         1.669001e-03                        1.669001e-03
# 97                                  NaN                                 NaN
# 98                                  NaN                                 NaN
# 99                                  NaN                                 NaN
# 100                                 NaN                                 NaN
#
# [101 rows x 55 columns]

# %%
for i in range(len(df.columns)):
    if df.columns[i]!='times' and 'het' in df.columns[i]:
        if i%3==1:
            if i==1:
                print(' \multirow{6}{*}{100} & \multirow{3}{*}{0.2} & ', end='')
            elif i==10 or i==6*3+10 or i==12*3+10:
                print(' & \multirow{3}{*}{0.4} & ', end='')
            elif i==6*3+1:
                print(' \multirow{6}{*}{1000} & \multirow{3}{*}{0.2} & ', end='')
            elif i==12*3+1:
                print(' \multirow{6}{*}{10000} & \multirow{3}{*}{0.2} & ', end='')
            else:
                print(' & & ', end='')
        if i%9==1:
            print('10\%', end=' & ')
        if i%9==4:
            print('40\%', end=' & ')
        if i%9==7:
            print('80\%', end=' & ')
            
        print(round(fun(df.columns[i]),5), end='')
        if not i%3:
            print(" \\\\")
        else:
            print(' & ', end='')
        if not i%(6*3):
            print(' \hline', end='')
# Out:
#  \multirow{6}{*}{100} & \multirow{3}{*}{0.2} & 10\% & 0.18435 & 0.17098 & 0.20162 \\
#  & & 40\% & 0.26741 & 0.22277 & 0.32298 \\
#  & & 80\% & 0.44848 & 0.44848 & 0.44848 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.13624 & 0.12444 & 0.15147 \\
#  & & 40\% & 0.2199 & 0.15286 & 0.30337 \\
#  & & 80\% & 0.1753 & 0.14206 & 0.2182 \\
#  \hline \multirow{6}{*}{1000} & \multirow{3}{*}{0.2} & 10\% & 0.17213 & 0.13847 & 0.2156 \\
#  & & 40\% & 0.17794 & 0.14736 & 0.21741 \\
#  & & 80\% & 0.12212 & 0.05817 & 0.20467 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.16356 & 0.13646 & 0.19731 \\
#  & & 40\% & 0.25603 & 0.20511 & 0.31944 \\
#  & & 80\% & 0.20424 & 0.06321 & 0.38632 \\
#  \hline \multirow{6}{*}{10000} & \multirow{3}{*}{0.2} & 10\% & 0.13218 & 0.1193 & 0.14882 \\
#  & & 40\% & 0.24944 & 0.19124 & 0.3219 \\
#  & & 80\% & 0.46124 & 0.46124 & 0.46124 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.08252 & 0.06782 & 0.1015 \\
#  & & 40\% & 0.25925 & 0.18888 & 0.34685 \\
#  & & 80\% & 0.12754 & 0.10535 & 0.15618 \\
#  \hline
