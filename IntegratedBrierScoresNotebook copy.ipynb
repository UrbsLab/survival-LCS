# %%
import pandas as pd
import numpy as np

# %%
homedir = 'pipeline_3'
df = pd.read_csv(homedir + '/ibs_data_all.csv')

# %%
def fun(col_name='me_f100_maf0.2_cens0.1'):
    temp_df = df[[col_name, 'times']]
    temp_df = temp_df.dropna()
    try:
        val = np.trapz(temp_df[col_name], temp_df['times']) / (list(temp_df['times'])[-1] - list(temp_df['times'])[0])
    except Exception as e:
#         print(col_name, e)
        val = np.nan
    return val

# %%
for col in df.columns:
    if col != 'times' and 'het' not in col:
        df_het = df.drop(col, axis=1)

# %%
for col in df.columns:
    if col != 'times' and 'add' not in col:
        df_add = df.drop(col, axis=1)

# %%
for col in df.columns:
    if col != 'times' and 'epi' not in col:
        df_epi = df.drop(col, axis=1)

# %%
for col in df.columns:
    if col != 'times' and 'me' not in col:
        df_me = df.drop(col, axis=1)

# %%
def make_latex_table(df):
    for i in range(len(df.columns)):
        if df.columns[i]!='times': #and 'het' in df.columns[i]:
            if i%3==1:
                if i==1:
                    print(' \multirow{6}{*}{100} & \multirow{3}{*}{0.2} & ', end='')
                elif i==10 or i==6*3+10 or i==12*3+10:
                    print(' & \multirow{3}{*}{0.4} & ', end='')
                elif i==6*3+1:
                    print(' \multirow{6}{*}{1000} & \multirow{3}{*}{0.2} & ', end='')
                elif i==12*3+1:
                    print(' \multirow{6}{*}{10000} & \multirow{3}{*}{0.2} & ', end='')
                else:
                    print(' & & ', end='')
            if i%9==1:
                print('10\%', end=' & ')
            if i%9==4:
                print('40\%', end=' & ')
            if i%9==7:
                print('80\%', end=' & ')
                
            print(round(fun(df.columns[i]),5), end='')
            if not i%3:
                print(" \\\\")
            else:
                print(' & ', end='')
            if not i%(6*3):
                print(' \hline', end='')

# %%
make_latex_table(df_me)
# Out:
#  \multirow{6}{*}{100} & \multirow{3}{*}{0.2} & 10\% & 0.08106 & 0.05034 & 0.11839 \\
#  & & 40\% & 0.20081 & 0.16392 & 0.24552 \\
#  & & 80\% & 0.35624 & 0.16449 & 0.58449 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.12514 & 0.08794 & 0.17022 \\
#  & & 40\% & 0.18182 & 0.10974 & 0.26747 \\
#  & & 80\% & 0.40309 & 0.05025 & 0.84131 \\
#  \hline \multirow{6}{*}{1000} & \multirow{3}{*}{0.2} & 10\% & 0.12194 & 0.07599 & 0.1764 \\
#  & & 40\% & 0.17642 & 0.09775 & 0.2699 \\
#  & & 80\% & 0.4671 & 0.19405 & 0.79114 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.15269 & 0.09614 & 0.21974 \\
#  & & 40\% & 0.20829 & 0.14498 & 0.28341 \\
#  & & 80\% & 0.26238 & 0.19252 & 0.35258 \\
#  \hline \multirow{6}{*}{10000} & \multirow{3}{*}{0.2} & 10\% & 0.14845 & 0.08104 & 0.22835 \\
#  & & 40\% & 0.12441 & 0.08155 & 0.17576 \\
#  & & 80\% & 0.41869 & 0.24341 & 0.62808 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.13093 & 0.11006 & 0.1562 \\
#  & & 40\% & 0.20941 & 0.12275 & 0.31211 \\
#  & & 80\% & 0.48561 & 0.14745 & 0.88939 \\
#  \hline & & 10\% & 0.07697 & 0.05739 & 0.10026 \\
#  & & 40\% & 0.17926 & 0.08997 & 0.28792 \\
#  & & 80\% & 0.36473 & 0.07641 & 0.71087 \\
#  & & 10\% & 0.16916 & 0.13096 & 0.21444 \\
#  & & 40\% & 0.11936 & 0.09085 & 0.1541 \\
#  & & 80\% & 0.30519 & 0.19901 & 0.43735 \\
#  \hline & & 10\% & 0.11727 & 0.09216 & 0.14768 \\
#  & & 40\% & 0.22826 & 0.14474 & 0.32747 \\
#  & & 80\% & 0.64077 & 0.54007 & 0.76614 \\
#  & & 10\% & 0.13993 & 0.1058 & 0.18039 \\
#  & & 40\% & 0.16637 & 0.11006 & 0.23497 \\
#  & & 80\% & 0.12783 & 0.06209 & 0.20589 \\
#  \hline & & 10\% & 0.05462 & 0.03713 & 0.07583 \\
#  & & 40\% & 0.11839 & 0.056 & 0.19307 \\
#  & & 80\% & nan & nan & nan \\
#  & & 10\% & 0.14588 & 0.10117 & 0.19886 \\
#  & & 40\% & 0.13838 & 0.10133 & 0.18231 \\
#  & & 80\% & 0.40146 & 0.18085 & 0.66432 \\
#  \hline & & 10\% & 0.19342 & 0.09604 & 0.31137 \\
#  & & 40\% & 0.21262 & 0.18483 & 0.24569 \\
#  & & 80\% & 0.38976 & 0.1204 & 0.71296 \\
#  & & 10\% & 0.0893 & 0.06256 & 0.12175 \\
#  & & 40\% & 0.19678 & 0.13445 & 0.27069 \\
#  & & 80\% & 0.39805 & 0.15842 & 0.68751 \\
#  \hline & & 10\% & 0.20076 & 0.15688 & 0.25404 \\
#  & & 40\% & 0.17095 & 0.11612 & 0.23597 \\
#  & & 80\% & 0.63683 & 0.34541 & 0.99149 \\
#  & & 10\% & 0.25856 & 0.1959 & 0.33282 \\
#  & & 40\% & 0.14485 & 0.07649 & 0.2261 \\
#  & & 80\% & 0.35025 & 0.16125 & 0.58039 \\
#  \hline & & 10\% & 0.21075 & 0.19938 & 0.22424 \\
#  & & 40\% & 0.22099 & 0.19235 & 0.25541 \\
#  & & 80\% & 0.44583 & 0.12471 & 0.828 \\
#  & & 10\% & 0.06313 & 0.05137 & 0.07749 \\
#  & & 40\% & 0.22726 & 0.14086 & 0.33221 \\
#  & & 80\% & 0.08356 & 0.02808 & 0.14932 \\
#  \hline & & 10\% & 0.12621 & 0.08582 & 0.17408 \\
#  & & 40\% & 0.11648 & 0.0849 & 0.15471 \\
#  & & 80\% & nan & nan & nan \\
#  & & 10\% & 0.05716 & 0.03068 & 0.08924 \\
#  & & 40\% & 0.05913 & 0.03712 & 0.08543 \\
#  & & 80\% & 0.47019 & 0.22675 & 0.76501 \\
#  \hline & & 10\% & 0.14047 & 0.11924 & 0.1662 \\
#  & & 40\% & 0.13805 & 0.07437 & 0.21519 \\
#  & & 80\% & 0.44203 & 0.15127 & 0.79588 \\
#  & & 10\% & 0.16417 & 0.11993 & 0.21668 \\
#  & & 40\% & 0.13663 & 0.09202 & 0.19123 \\
#  & & 80\% & 0.14593 & 0.06366 & 0.24346 \\
#  \hline & & 10\% & 0.10919 & 0.08078 & 0.14382 \\
#  & & 40\% & 0.29424 & 0.2041 & 0.40189 \\
#  & & 80\% & 1.20188 & -0.41635 & 3.28079 \\
#  & & 10\% & 0.1127 & 0.08941 & 0.14096 \\
#  & & 40\% & 0.03188 & 0.02059 & 0.04543 \\
#  & & 80\% & 0.21832 & 0.11943 &

# %%
make_latex_table(df_epi)
# Out:
#  \multirow{6}{*}{100} & \multirow{3}{*}{0.2} & 10\% & 0.08106 & 0.05034 & 0.11839 \\
#  & & 40\% & 0.20081 & 0.16392 & 0.24552 \\
#  & & 80\% & 0.35624 & 0.16449 & 0.58449 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.12514 & 0.08794 & 0.17022 \\
#  & & 40\% & 0.18182 & 0.10974 & 0.26747 \\
#  & & 80\% & 0.40309 & 0.05025 & 0.84131 \\
#  \hline \multirow{6}{*}{1000} & \multirow{3}{*}{0.2} & 10\% & 0.12194 & 0.07599 & 0.1764 \\
#  & & 40\% & 0.17642 & 0.09775 & 0.2699 \\
#  & & 80\% & 0.4671 & 0.19405 & 0.79114 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.15269 & 0.09614 & 0.21974 \\
#  & & 40\% & 0.20829 & 0.14498 & 0.28341 \\
#  & & 80\% & 0.26238 & 0.19252 & 0.35258 \\
#  \hline \multirow{6}{*}{10000} & \multirow{3}{*}{0.2} & 10\% & 0.14845 & 0.08104 & 0.22835 \\
#  & & 40\% & 0.12441 & 0.08155 & 0.17576 \\
#  & & 80\% & 0.41869 & 0.24341 & 0.62808 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.13093 & 0.11006 & 0.1562 \\
#  & & 40\% & 0.20941 & 0.12275 & 0.31211 \\
#  & & 80\% & 0.48561 & 0.14745 & 0.88939 \\
#  \hline & & 10\% & 0.07697 & 0.05739 & 0.10026 \\
#  & & 40\% & 0.17926 & 0.08997 & 0.28792 \\
#  & & 80\% & 0.36473 & 0.07641 & 0.71087 \\
#  & & 10\% & 0.16916 & 0.13096 & 0.21444 \\
#  & & 40\% & 0.11936 & 0.09085 & 0.1541 \\
#  & & 80\% & 0.30519 & 0.19901 & 0.43735 \\
#  \hline & & 10\% & 0.11727 & 0.09216 & 0.14768 \\
#  & & 40\% & 0.22826 & 0.14474 & 0.32747 \\
#  & & 80\% & 0.64077 & 0.54007 & 0.76614 \\
#  & & 10\% & 0.13993 & 0.1058 & 0.18039 \\
#  & & 40\% & 0.16637 & 0.11006 & 0.23497 \\
#  & & 80\% & 0.12783 & 0.06209 & 0.20589 \\
#  \hline & & 10\% & 0.05462 & 0.03713 & 0.07583 \\
#  & & 40\% & 0.11839 & 0.056 & 0.19307 \\
#  & & 80\% & nan & nan & nan \\
#  & & 10\% & 0.14588 & 0.10117 & 0.19886 \\
#  & & 40\% & 0.13838 & 0.10133 & 0.18231 \\
#  & & 80\% & 0.40146 & 0.18085 & 0.66432 \\
#  \hline & & 10\% & 0.19342 & 0.09604 & 0.31137 \\
#  & & 40\% & 0.21262 & 0.18483 & 0.24569 \\
#  & & 80\% & 0.38976 & 0.1204 & 0.71296 \\
#  & & 10\% & 0.0893 & 0.06256 & 0.12175 \\
#  & & 40\% & 0.19678 & 0.13445 & 0.27069 \\
#  & & 80\% & 0.39805 & 0.15842 & 0.68751 \\
#  \hline & & 10\% & 0.20076 & 0.15688 & 0.25404 \\
#  & & 40\% & 0.17095 & 0.11612 & 0.23597 \\
#  & & 80\% & 0.63683 & 0.34541 & 0.99149 \\
#  & & 10\% & 0.25856 & 0.1959 & 0.33282 \\
#  & & 40\% & 0.14485 & 0.07649 & 0.2261 \\
#  & & 80\% & 0.35025 & 0.16125 & 0.58039 \\
#  \hline & & 10\% & 0.21075 & 0.19938 & 0.22424 \\
#  & & 40\% & 0.22099 & 0.19235 & 0.25541 \\
#  & & 80\% & 0.44583 & 0.12471 & 0.828 \\
#  & & 10\% & 0.06313 & 0.05137 & 0.07749 \\
#  & & 40\% & 0.22726 & 0.14086 & 0.33221 \\
#  & & 80\% & 0.08356 & 0.02808 & 0.14932 \\
#  \hline & & 10\% & 0.12621 & 0.08582 & 0.17408 \\
#  & & 40\% & 0.11648 & 0.0849 & 0.15471 \\
#  & & 80\% & nan & nan & nan \\
#  & & 10\% & 0.05716 & 0.03068 & 0.08924 \\
#  & & 40\% & 0.05913 & 0.03712 & 0.08543 \\
#  & & 80\% & 0.47019 & 0.22675 & 0.76501 \\
#  \hline & & 10\% & 0.14047 & 0.11924 & 0.1662 \\
#  & & 40\% & 0.13805 & 0.07437 & 0.21519 \\
#  & & 80\% & 0.44203 & 0.15127 & 0.79588 \\
#  & & 10\% & 0.16417 & 0.11993 & 0.21668 \\
#  & & 40\% & 0.13663 & 0.09202 & 0.19123 \\
#  & & 80\% & 0.14593 & 0.06366 & 0.24346 \\
#  \hline & & 10\% & 0.10919 & 0.08078 & 0.14382 \\
#  & & 40\% & 0.29424 & 0.2041 & 0.40189 \\
#  & & 80\% & 1.20188 & -0.41635 & 3.28079 \\
#  & & 10\% & 0.1127 & 0.08941 & 0.14096 \\
#  & & 40\% & 0.03188 & 0.02059 & 0.04543 \\
#  & & 80\% & 0.21832 & 0.11943 &

# %%
make_latex_table(df_het)
# Out:
#  \multirow{6}{*}{100} & \multirow{3}{*}{0.2} & 10\% & 0.08106 & 0.05034 & 0.11839 \\
#  & & 40\% & 0.20081 & 0.16392 & 0.24552 \\
#  & & 80\% & 0.35624 & 0.16449 & 0.58449 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.12514 & 0.08794 & 0.17022 \\
#  & & 40\% & 0.18182 & 0.10974 & 0.26747 \\
#  & & 80\% & 0.40309 & 0.05025 & 0.84131 \\
#  \hline \multirow{6}{*}{1000} & \multirow{3}{*}{0.2} & 10\% & 0.12194 & 0.07599 & 0.1764 \\
#  & & 40\% & 0.17642 & 0.09775 & 0.2699 \\
#  & & 80\% & 0.4671 & 0.19405 & 0.79114 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.15269 & 0.09614 & 0.21974 \\
#  & & 40\% & 0.20829 & 0.14498 & 0.28341 \\
#  & & 80\% & 0.26238 & 0.19252 & 0.35258 \\
#  \hline \multirow{6}{*}{10000} & \multirow{3}{*}{0.2} & 10\% & 0.14845 & 0.08104 & 0.22835 \\
#  & & 40\% & 0.12441 & 0.08155 & 0.17576 \\
#  & & 80\% & 0.41869 & 0.24341 & 0.62808 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.13093 & 0.11006 & 0.1562 \\
#  & & 40\% & 0.20941 & 0.12275 & 0.31211 \\
#  & & 80\% & 0.48561 & 0.14745 & 0.88939 \\
#  \hline & & 10\% & 0.07697 & 0.05739 & 0.10026 \\
#  & & 40\% & 0.17926 & 0.08997 & 0.28792 \\
#  & & 80\% & 0.36473 & 0.07641 & 0.71087 \\
#  & & 10\% & 0.16916 & 0.13096 & 0.21444 \\
#  & & 40\% & 0.11936 & 0.09085 & 0.1541 \\
#  & & 80\% & 0.30519 & 0.19901 & 0.43735 \\
#  \hline & & 10\% & 0.11727 & 0.09216 & 0.14768 \\
#  & & 40\% & 0.22826 & 0.14474 & 0.32747 \\
#  & & 80\% & 0.64077 & 0.54007 & 0.76614 \\
#  & & 10\% & 0.13993 & 0.1058 & 0.18039 \\
#  & & 40\% & 0.16637 & 0.11006 & 0.23497 \\
#  & & 80\% & 0.12783 & 0.06209 & 0.20589 \\
#  \hline & & 10\% & 0.05462 & 0.03713 & 0.07583 \\
#  & & 40\% & 0.11839 & 0.056 & 0.19307 \\
#  & & 80\% & nan & nan & nan \\
#  & & 10\% & 0.14588 & 0.10117 & 0.19886 \\
#  & & 40\% & 0.13838 & 0.10133 & 0.18231 \\
#  & & 80\% & 0.40146 & 0.18085 & 0.66432 \\
#  \hline & & 10\% & 0.19342 & 0.09604 & 0.31137 \\
#  & & 40\% & 0.21262 & 0.18483 & 0.24569 \\
#  & & 80\% & 0.38976 & 0.1204 & 0.71296 \\
#  & & 10\% & 0.0893 & 0.06256 & 0.12175 \\
#  & & 40\% & 0.19678 & 0.13445 & 0.27069 \\
#  & & 80\% & 0.39805 & 0.15842 & 0.68751 \\
#  \hline & & 10\% & 0.20076 & 0.15688 & 0.25404 \\
#  & & 40\% & 0.17095 & 0.11612 & 0.23597 \\
#  & & 80\% & 0.63683 & 0.34541 & 0.99149 \\
#  & & 10\% & 0.25856 & 0.1959 & 0.33282 \\
#  & & 40\% & 0.14485 & 0.07649 & 0.2261 \\
#  & & 80\% & 0.35025 & 0.16125 & 0.58039 \\
#  \hline & & 10\% & 0.21075 & 0.19938 & 0.22424 \\
#  & & 40\% & 0.22099 & 0.19235 & 0.25541 \\
#  & & 80\% & 0.44583 & 0.12471 & 0.828 \\
#  & & 10\% & 0.06313 & 0.05137 & 0.07749 \\
#  & & 40\% & 0.22726 & 0.14086 & 0.33221 \\
#  & & 80\% & 0.08356 & 0.02808 & 0.14932 \\
#  \hline & & 10\% & 0.12621 & 0.08582 & 0.17408 \\
#  & & 40\% & 0.11648 & 0.0849 & 0.15471 \\
#  & & 80\% & nan & nan & nan \\
#  & & 10\% & 0.05716 & 0.03068 & 0.08924 \\
#  & & 40\% & 0.05913 & 0.03712 & 0.08543 \\
#  & & 80\% & 0.47019 & 0.22675 & 0.76501 \\
#  \hline & & 10\% & 0.14047 & 0.11924 & 0.1662 \\
#  & & 40\% & 0.13805 & 0.07437 & 0.21519 \\
#  & & 80\% & 0.44203 & 0.15127 & 0.79588 \\
#  & & 10\% & 0.16417 & 0.11993 & 0.21668 \\
#  & & 40\% & 0.13663 & 0.09202 & 0.19123 \\
#  & & 80\% & 0.14593 & 0.06366 & 0.24346 \\
#  \hline & & 10\% & 0.10919 & 0.08078 & 0.14382 \\
#  & & 40\% & 0.29424 & 0.2041 & 0.40189 \\
#  & & 80\% & 1.20188 & -0.41635 & 3.28079 \\
#  & & 10\% & 0.1127 & 0.08941 & 0.14096 \\
#  & & 40\% & 0.03188 & 0.02059 & 0.04543 \\
#  & & 80\% & 0.21832 & 0.11943 &

# %%
make_latex_table(df_add)
# Out:
#  \multirow{6}{*}{100} & \multirow{3}{*}{0.2} & 10\% & 0.08106 & 0.05034 & 0.11839 \\
#  & & 40\% & 0.20081 & 0.16392 & 0.24552 \\
#  & & 80\% & 0.35624 & 0.16449 & 0.58449 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.12514 & 0.08794 & 0.17022 \\
#  & & 40\% & 0.18182 & 0.10974 & 0.26747 \\
#  & & 80\% & 0.40309 & 0.05025 & 0.84131 \\
#  \hline \multirow{6}{*}{1000} & \multirow{3}{*}{0.2} & 10\% & 0.12194 & 0.07599 & 0.1764 \\
#  & & 40\% & 0.17642 & 0.09775 & 0.2699 \\
#  & & 80\% & 0.4671 & 0.19405 & 0.79114 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.15269 & 0.09614 & 0.21974 \\
#  & & 40\% & 0.20829 & 0.14498 & 0.28341 \\
#  & & 80\% & 0.26238 & 0.19252 & 0.35258 \\
#  \hline \multirow{6}{*}{10000} & \multirow{3}{*}{0.2} & 10\% & 0.14845 & 0.08104 & 0.22835 \\
#  & & 40\% & 0.12441 & 0.08155 & 0.17576 \\
#  & & 80\% & 0.41869 & 0.24341 & 0.62808 \\
#  & \multirow{3}{*}{0.4} & 10\% & 0.13093 & 0.11006 & 0.1562 \\
#  & & 40\% & 0.20941 & 0.12275 & 0.31211 \\
#  & & 80\% & 0.48561 & 0.14745 & 0.88939 \\
#  \hline & & 10\% & 0.07697 & 0.05739 & 0.10026 \\
#  & & 40\% & 0.17926 & 0.08997 & 0.28792 \\
#  & & 80\% & 0.36473 & 0.07641 & 0.71087 \\
#  & & 10\% & 0.16916 & 0.13096 & 0.21444 \\
#  & & 40\% & 0.11936 & 0.09085 & 0.1541 \\
#  & & 80\% & 0.30519 & 0.19901 & 0.43735 \\
#  \hline & & 10\% & 0.11727 & 0.09216 & 0.14768 \\
#  & & 40\% & 0.22826 & 0.14474 & 0.32747 \\
#  & & 80\% & 0.64077 & 0.54007 & 0.76614 \\
#  & & 10\% & 0.13993 & 0.1058 & 0.18039 \\
#  & & 40\% & 0.16637 & 0.11006 & 0.23497 \\
#  & & 80\% & 0.12783 & 0.06209 & 0.20589 \\
#  \hline & & 10\% & 0.05462 & 0.03713 & 0.07583 \\
#  & & 40\% & 0.11839 & 0.056 & 0.19307 \\
#  & & 80\% & nan & nan & nan \\
#  & & 10\% & 0.14588 & 0.10117 & 0.19886 \\
#  & & 40\% & 0.13838 & 0.10133 & 0.18231 \\
#  & & 80\% & 0.40146 & 0.18085 & 0.66432 \\
#  \hline & & 10\% & 0.19342 & 0.09604 & 0.31137 \\
#  & & 40\% & 0.21262 & 0.18483 & 0.24569 \\
#  & & 80\% & 0.38976 & 0.1204 & 0.71296 \\
#  & & 10\% & 0.0893 & 0.06256 & 0.12175 \\
#  & & 40\% & 0.19678 & 0.13445 & 0.27069 \\
#  & & 80\% & 0.39805 & 0.15842 & 0.68751 \\
#  \hline & & 10\% & 0.20076 & 0.15688 & 0.25404 \\
#  & & 40\% & 0.17095 & 0.11612 & 0.23597 \\
#  & & 80\% & 0.63683 & 0.34541 & 0.99149 \\
#  & & 10\% & 0.25856 & 0.1959 & 0.33282 \\
#  & & 40\% & 0.14485 & 0.07649 & 0.2261 \\
#  & & 80\% & 0.35025 & 0.16125 & 0.58039 \\
#  \hline & & 10\% & 0.21075 & 0.19938 & 0.22424 \\
#  & & 40\% & 0.22099 & 0.19235 & 0.25541 \\
#  & & 80\% & 0.44583 & 0.12471 & 0.828 \\
#  & & 10\% & 0.06313 & 0.05137 & 0.07749 \\
#  & & 40\% & 0.22726 & 0.14086 & 0.33221 \\
#  & & 80\% & 0.08356 & 0.02808 & 0.12621 \\
#  \hline & & 10\% & 0.08582 & 0.17408 & 0.11648 \\
#  & & 40\% & 0.0849 & 0.15471 & nan \\
#  & & 80\% & nan & nan & 0.05716 \\
#  & & 10\% &
# 0.03068 & 0.08924 & 0.05913 \\
#  & & 40\% & 0.03712 & 0.08543 & 0.47019 \\
#  & & 80\% & 0.22675 & 0.76501 & 0.14047 \\
#  \hline & & 10\% & 0.11924 & 0.1662 & 0.13805 \\
#  & & 40\% & 0.07437 & 0.21519 & 0.44203 \\
#  & & 80\% & 0.15127 & 0.79588 & 0.16417 \\
#  & & 10\% & 0.11993 & 0.21668 & 0.13663 \\
#  & & 40\% & 0.09202 & 0.19123 & 0.14593 \\
#  & & 80\% & 0.06366 & 0.24346 & 0.10919 \\
#  \hline & & 10\% & 0.08078 & 0.14382 & 0.29424 \\
#  & & 40\% & 0.2041 & 0.40189 & 1.20188 \\
#  & & 80\% & -0.41635 & 3.28079 & 0.1127 \\
#  & & 10\% & 0.08941 & 0.14096 & 0.03188 \\
#  & & 40\% & 0.02059 & 0.04543 & 0.21832 \\
#  & & 80\% & 0.11943 & 0.33617 &
